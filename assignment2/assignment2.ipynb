# %%
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing()

# %%
import pandas as pd
df = pd.DataFrame(california.data, columns=california.feature_names)
df_target = pd.DataFrame(california.target, columns=["Target"])

# %%
import numpy as np

# %%
bins = [0.2, 1.7, 2.5, 5]
labels = ["level_1", "level_2", "level_3"]

# %%
def make_onehot(df, target, bins, labels):
    target = pd.cut(target['Target'], bins= bins, labels= labels)
    target = target.dropna()
    target = pd.get_dummies(target)
    
    tpp = pd.concat([df, target], axis= 1, join= "inner")
    return tpp

# %%
data = make_onehot(df, target = df_target, bins= bins, labels=labels)

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  level_1  level_2  level_3
# 0        -122.23        0        0        1
# 1        -122.22        0        0        1
# 2        -122.24        0        0        1
# 3        -122.25        0        0        1
# 4        -122.25        0        0        1
# ...          ...      ...      ...      ...
# 20635    -121.09        1        0        0
# 20636    -121.21        1        0        0
# 20637    -121.22        1        0        0
# 20638    -121.32        1        0        0
# 20639    -121.24        1        0        0
#
# [19670 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7,4))
plt.xlabel('Medlnc', fontsize= 14)
plt.ylabel('Longitude', fontsize= 14)
plt.title('problem 2')
plt.scatter(data.MedInc, data.Longitude, s= data.level_1, c= 'r', label= labels[0])
plt.scatter(data.MedInc, data.Longitude, s= data.level_2, c= 'b', label= labels[1])
plt.scatter(data.MedInc, data.Longitude, s= data.level_3, c= 'purple', label= labels[2])
plt.legend()
plt.show()

# %%
from sklearn.datasets import make_blobs
import seaborn as sns

# %%
X, y = make_blobs(n_samples=300, n_features=2, centers=3, random_state=1, cluster_std = 0.001)
X2, _ = make_blobs(n_samples=300, n_features=2, centers=1, random_state=1, cluster_std = 1)
X = np.vstack([X, X2])
plt.scatter(X[:, 0], X[:, 1], marker='o', s=100, edgecolor="k", linewidth=2)
plt.show()

# %%
X[:, 0]= X[:, 0]+np.random.normal(0, 0.45, len(X[:, 0]))
X[:, 1]= X[: ,1]+np.random.normal(0, 0.45, len(X[:, 1]))

# %%
plt.scatter(X[:, 0], X[:, 1], marker='o', s=100, edgecolor="k", linewidth=2)
